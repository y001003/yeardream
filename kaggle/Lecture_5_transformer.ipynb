# %% [markdown]
# <a href="https://colab.research.google.com/github/y001003/yeardream/blob/main/kaggle/Lecture_5_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #복습 과제

# %% [markdown]
# ## **Problem 1**

# %% [markdown]
# ### 1) Language translation (e.g. 스페인어->영어) task에 있어 일반적인 형식의 Many-to-Many RNN이 적합하지 않은 이유를 설명하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
#
# 어순이나 단어의 갯수가 다르면 다음것을 예측하는 RNN 의 구조로는 예측하도록 맞추기가 어렵다.

# %% [markdown]
# ### 2) Sequence-to-sequence 모델의 구조와 작동방식을 서술하고, Decoder에서 Teacher forcing이 활용되는 이유를 설명하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
#
# 인코더와 디코더의 모델구조를 가지고, 인코더에서 모든 단어들을 순차적으로 입력받은 후에 하나의 벡터로 만든다. 디코더는 이 받은 벡터를 받아서 번역하여 하나씩 출력한다. Teacher forcing은 학습할 때 decoder의 입력값으로 정답을 입력하도록하는 것이다. 왜냐하면 앞에서 잘못된 출력을 내었을 때 이를 그대로 다음 스탭에 적용할 경우 잘못된 학습을 계속해서 할 가능성이 있기 때문이다.

# %% [markdown]
# ### 3) Input Sequence가 길어짐에 따라 Sequence-to-sequence 모델에서 발생할 수 있는 문제와 그 원인을 서술하고 Attention을 통해 이를 어떻게 개선할 수 있는지 서술하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
# Sequence to sequence는 문장이 길어져도 이를 인코더에서 하나의 벡터로 만들어서 디코더로 보내기 때문에 하나의 벡터로 만드는 과정에서 정보의 손실이 일어날 가능성이 크다.

# %% [markdown]
# ### 4) BERT의 기반이 되는 두 가지 태스크(MLM, NSP)에 대해 간단히 설명하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)

# %% [markdown]
# ### 5) Vision Transformer가 small dataset에서는 기존의 CNN 기반 모델에 비해 성능이 떨어지지만 large dataset에서는 더 뛰어난 성능을 보이는 이유에 대해 설명하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)

# %% [markdown]
# ## **Problem 2**

# %% [markdown]
# ### 1) 다음 수식에 기초하여 Transformer에서 Multi-head self-attention을 계산하는 전체 과정을 상세히 설명하시오.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (답안을 여기에 작성해주세요)
# 각각 query, key, value를 가진 어텐션을 여러개 만들어서 어텐션 벨류 메트릭스를 구하고 이를 CONCAT해서 합친다. 그리고 그것을 W 로 변환하여 하나의 메트릭스로 만든다.

# %% [markdown]
# ### 2) 위 수식에서 $QK^\top$를 $\sqrt{d_k}$로 나누어주는 이유를 설명하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
# QK 의 크기가 너무 커지면 softmax를 취했을 때 기울기가 0이 된다. 그렇기 때문에 나누어줘서 조금더 스케일을 조정하는 것이다.

# %% [markdown]
# ### 3) 위 수식에서 softmax의 역할이 무엇인지 설명하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
# Q와 K의 유사도가 높은 벡터에 가중치를 더 높게 주는 역할을 가진다.

# %% [markdown]
# ### 4) "Multi-head" attention을 사용함으로써 얻을 수 있는 이점에 대해 설명하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
# 단어의 여러가지 중의적인 의미와 맥락에서 나타나는 의미를 파악할 수 있다.

# %% [markdown]
# ### 5) 다음 도식도에 기초하여 Transformer 모델의 구조와 작동방식에 대해 설명하시오 (세부적인 연산과정보다는 Inputs이 Encoder와 Decoder를 거쳐 Output Probabilities로 이어지는 전체적인 흐름을 단계적으로 서술).

# %% [markdown]
# (답안을 여기에 작성해주세요)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 6) Transformer 모델에서 positional encoding이 필요한 이유에 대해 서술하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
# 임베딩된 단어가 들어갈 때, 그 임베딩된 벡터에 대한 고유 위치 정보가 기록된다. Self attention과정에서 위치정보가 소실되는데 이 positional Encoding을 통해 위치를 기억하게끔 만들어준다.

# %% [markdown]
# ### 7) 위 도식도에서 Add & Norm이 의미하는 바가 무엇인지 서술하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
# 어탠션 학습을 거치전 원래 값과 합쳐서 Norm해주는 것으로 손실된 원본 정보를 어느정도 보강시켜 학습을 안정화 시켜주는 역할을 한다.

# %% [markdown]
# ### 8) Decoder에서 "Masked" Multi-head attention이 사용되는 이유에 대해 서술하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
# 정답지를 Decoder의 Input으로 받는데 Mask를 해서 뒤에 있는 단어를 못보게 만들어서 정답지의 다음 단어를 맞추는 학습을 시킨다.

# %% [markdown]
# ### 9) Decoder의 Encoder-Decoder Attention Layer에서 Input이 무엇인지 서술하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)
# 인코더에서 만들어진 키와 벨류

# %% [markdown]
# ### 10) RNN기반 모델과 비교하여 Transformer 모델을 사용함으로써 얻을 수 있는 이점에 대해 서술하시오.

# %% [markdown]
# (답안을 여기에 작성해주세요)

# %% [markdown]
# . 문장을 한번에 넣어서 정보손실이 적다.

# %% [markdown]
# . 병렬연산이 가능하다.

# %% [markdown]
# .

# %% [markdown]
# #실습 과제

# %% [markdown]
# ## Exercise 1. 강의 슬라이드 내 Implementation Example을 참고하여 SelfAttention 클래스를 작성하고, 수업시간에 배운 내용이 실제 코드로 어떻게 구현될 수 있는지 분석해보시오.

# %%
import torch
import torch.nn as nn

class SelfAttention(nn.Module):
    def __init__(self, embed_size, heads):
        super(SelfAttention, self).__init__()

        ### Complete Here ###
        self.embed_size = embed_size # 들어온 단어의 수
        self.heads = heads # 헤드의 디멘션
        self.head_dim = embed_size // heads # 병렬로 처리할 멀티헤드의 수

        self.values = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.keys = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.queries = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.fc_out = nn.Linear(heads * self.head_dim, embed_size)




        ### Complete Here ###


    def forward(self, values, keys, query, mask):

        ### Complete Here ###









        ### Complete Here ###

        return out

# %% [markdown]
# ## Exercise 2. 강의 슬라이드 내 Implementation Example을 참고하여 TransformerBlock 클래스를 작성하고, 수업시간에 배운 내용이 실제 코드로 어떻게 구현될 수 있는지 분석해보시오.

# %%
import torch
import torch.nn as nn

class TransformerBlock(nn.Module):
    def __init__(self, embed_size, heads, dropout, forward_expansion):
        super(TransformerBlock, self).__init__()

        ### Complete Here ###










        ### Complete Here ###


    def forward(self, value, key, query, mask):

        ### Complete Here ###










        ### Complete Here ###

        return out
