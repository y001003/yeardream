# %% [markdown]
# <a href="https://colab.research.google.com/github/y001003/yeardream/blob/main/ML/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EB%B6%84%EB%A5%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 분류모델 Classification
#
# 주어진 데이터(X)를 분류하고자 하는 값(y)에 할당하는 방법

# %% [markdown]
# Classification Model
# 1. Linear Classifier
# 2. Logistic Regression
# 3. Naive Bayes
# 4. KNN
# 5. SVM
# 6. Random Forest
# 7. Neural Network

# %% [markdown]
# ## 1. Linear Classifier
#
# Linear Classifier : $y = Wx + b$로 표시되는 선형 함수로 데이터를 분류하는 모델.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 경계면을 decision boundary(linear classifier)로 삼아 위를 1 아래를 0으로 분류한다.

# %% [markdown]
# ## 2, Logistic Regression
#
# Logistic Regression : 주어진 데이터(X)를 통해서 사건의 발생 확률(y)를 예측하는 통계 모델

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Linear Regression 결과에 적당한 함수를 적용하여 output score를 0과 1사이의 값으로 변환하는 것으로 카테고리가 나올 확률을 예측하는 문제로 변환합니다.
#
# 이 확률값은 예측값이 1이 될 확률이며, 이 확률이 0.5를 넘기면 1로 예측하고 그렇지 않다면 0으로 예측을 하는 분류 모델로써 사용할 수 있습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# logistic function(sigmoid function)
#
# $$
# S(x) = \frac{1}{1+e^{-Wx+b}}
# $$
# $$
# logit function(z) = \frac{1}{1+e^{-z}}
# $$

# %% [markdown]
# logit function에 input x 값이 들어가면 y는 0~1 사이의 값이 출력된다. 그리고 그 값이 0.5를 넘으면 1이라고 예측값을 출력 0.5보다 낮으면 0을 출력합니다.
