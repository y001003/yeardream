# %% [markdown]
# # CNN - 기초 Again

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import PIL
import os

# %% [markdown]
# # 1. 기본 이미지 변수로 다루기

# %%
# 현재 폴더에 파일들 확인하기
os.listdir()
# Out:
# ['.ipynb_checkpoints', '01.ImageLoad.ipynb', 'TEST', 'TRAIN']

# %%
# TRAIN 폴더 내에 class에 따라 이미지들이 저장되어있음
os.listdir('TRAIN')
# Out:
# ['akiec', 'bcc', 'melanoma']

# %%
# Akiec 이미지들 목록 출력
os.listdir('TRAIN/akiec')[:3]
# Out:
# ['ISIC_0024372.jpg', 'ISIC_0024418.jpg', 'ISIC_0024450.jpg']

# %%
# 이미지 읽기
Image = PIL.Image.open('TRAIN/akiec/ISIC_0024372.jpg')

# %%
Image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450>

# %%
np.array(Image)[:5, :5, 0]
# Out:
# array([[145, 148, 147, 150, 151],
#        [143, 146, 146, 148, 151],
#        [140, 144, 148, 149, 149],
#        [138, 144, 151, 152, 152],
#        [133, 138, 148, 152, 154]], dtype=uint8)

# %%
PIL.Image.open('TRAIN/akiec/ISIC_0024372.jpg').resize([224, 224])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# # 2. 이미지 여러장 읽기

# %%
ImageSize = (56, 56)

# %% [markdown]
# ## Train 데이터 모두 읽기

# %%
Train_x = []
Train_y = []
for FileName in os.listdir('TRAIN/akiec/'):
    Train_x.append(PIL.Image.open('TRAIN/akiec/' + FileName).resize(ImageSize))
    Train_y.append(0)
    
for FileName in os.listdir('TRAIN/melanoma/'):
    Train_x.append(PIL.Image.open('TRAIN/melanoma/' + FileName).resize(ImageSize))
    Train_y.append(1)

# %%
Train_x = np.stack(Train_x, axis=0 )
Train_y = np.array(Train_y)

# %%
print(Train_x.shape)
print(Train_y.shape)
# Out:
# (540, 56, 56, 3)
# (540,)

# %% [markdown]
# # Test 데이터 모두 읽기

# %%
# List로 모든 이미지 읽은 후, numpy array로 수정
Test_x = []
Test_y = []
for FileName in os.listdir('Test/akiec/'):
    Test_x.append(PIL.Image.open('Test/akiec/' + FileName).resize(ImageSize))
    Test_y.append(0)
    
for FileName in os.listdir('Test/melanoma/'):
    Test_x.append(PIL.Image.open('Test/melanoma/' + FileName).resize(ImageSize))
    Test_y.append(1)

# %%
Test_x = np.stack(Test_x, axis=0 )
Test_y = np.array(Test_y)

# %%
print(Train_x.shape)
print(Train_y.shape)
# Out:
# (540, 56, 56, 3)
# (540,)

# %%
plt.imshow(Train_x[0], interpolation='nearest')
plt.show()

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# # 3. 가장 기본적인 CNN 모델 구현하기

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(1, (3, 3), activation='linear', input_shape=(56, 56, 3,)))

model = Model(inputs=model.input, outputs=model.output)

# %% [markdown]
# Parameter가 28개인 이유: RGB 3개의 56*56에 따른 3*3 filter 3개 + 상수 b<br>
#
# (3 * 3) (filter) * 3 (RGB) + 1 (constant) = 28

# %%
# filter size: 3*3 이므로, 56*56 -> 54*54로 이미지 크기 줄어듬
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10_input (InputLayer  [(None, 56, 56, 3)]      0
#  )
#
#  conv2d_10 (Conv2D)          (None, 54, 54, 1)         28
#
# =================================================================
# Total params: 28
# Trainable params: 28
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Input의 shape 및 prediction을 통한 연산

# %%
Test_x[:1].shape
# Out:
# (1, 56, 56, 3)

# %%
Predicted = model.predict(Test_x[:1])
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001970F7C7E20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 31ms/step

# %%
Predicted.shape
# Out:
# (1, 54, 54, 1)

# %%
fig = plt.figure(figsize=(6, 3))

fig.add_subplot(1, 2, 1) # row, column, n번째 image
plt.imshow(Test_x[0], interpolation='nearest')

fig.add_subplot(1, 2, 2)
plt.imshow(Predicted[0], interpolation='nearest', cmap = 'gray')

# %%
weights = model.get_weights()

# %%
weights[0].shape
# Out:
# (3, 3, 3, 1)

# %% [markdown]
# 3 (filter 3)<br>
# 3 (filter 3)<br>
# 3 (RGB 3)<br>
# 3 (unit 1)<br>

# %%
from IPython.display import Image
Image('CNN.png')

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# # 4. Padding이 포함된 Convolution 구현하기

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(1, (3, 3), activation='linear', padding='same', input_shape=(56, 56, 3,)))

model = Model(inputs=model.input, outputs=model.output)

# %%
model.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13_input (InputLayer  [(None, 56, 56, 3)]      0
#  )
#
#  conv2d_13 (Conv2D)          (None, 56, 56, 1)         28
#
# =================================================================
# Total params: 28
# Trainable params: 28
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# # 5. Unit이 여러개인 Convolution

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='linear', padding='same', input_shape=(56, 56, 3,)))

model = Model(inputs=model.input, outputs=model.output)

# %%
model.summary()
# Out:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14_input (InputLayer  [(None, 56, 56, 3)]      0
#  )
#
#  conv2d_14 (Conv2D)          (None, 56, 56, 5)         140
#
# =================================================================
# Total params: 140
# Trainable params: 140
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 9: Filter 3*3
# 3: RGB
# 5: Unit 5
# +5 : Constants

(9 * 3 * 5) + 5
# Out:
# 140

# %%
# 예측값 확인하기
Predicted = model.predict(Train_x[:3])
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
Predicted.shape
# Out:
# (3, 56, 56, 5)

# %%
Weights = model.get_weights()
len(Weights)
# Out:
# 2

# %%
Weights[0].shape
# Out:
# (3, 3, 3, 5)

# %% [markdown]
# 3 (filter 3)<br>
# 3 (filter 3)<br>
# 3 (RGB 3)<br>
# 5 (unit 5)<br>

# %% [markdown]
# <br><br><br><br><br><br>

# %% [markdown]
# activation function: relu

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model = Model(inputs=model.input, outputs=model.output)

# %%
Predicted = model.predict(Test_x[:1])
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %% [markdown]
# <결과값에 0 미만이 존재하지 않음>

# %%
Predicted[0]
# Out:
# array([[[ 49.6791   ,   0.       ,   0.       , 124.509636 ,
#           85.907135 ],
#         [ 41.74849  ,   0.       ,   5.4747844,  94.83343  ,
#           16.835434 ],
#         [ 42.722507 ,   0.       ,   4.4612765,  96.48482  ,
#           16.937418 ],
#         ...,
#         [ 48.80371  ,   0.       ,  10.18391  , 103.14478  ,
#            9.928392 ],
#         [ 45.563225 ,   0.       ,  11.385093 , 103.16427  ,
#           10.901199 ],
#         [  0.       ,   0.       ,   0.       ,  56.726494 ,
#            0.       ]],
#
#        [[  0.       ,   0.       ,   0.       , 201.04451  ,
#           59.31295  ],
#         [  0.       ,   0.       ,   0.       , 203.21893  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 206.0573   ,
#            0.       ],
#         ...,
#         [  0.       ,   0.       ,   0.       , 236.60219  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 223.18716  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 159.43233  ,
#            0.       ]],
#
#        [[  1.8879533,   0.       ,   0.       , 204.36452  ,
#           60.888237 ],
#         [  0.       ,   0.       ,   0.       , 209.09698  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 210.49242  ,
#            0.       ],
#         ...,
#         [  0.       ,   0.       ,   0.       , 238.15448  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 226.903    ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 164.12585  ,
#            0.       ]],
#
#        ...,
#
#        [[  0.       ,   0.       ,   0.       , 188.40057  ,
#           52.518814 ],
#         [  0.       ,   0.       ,   0.       , 196.87497  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 200.52588  ,
#            0.       ],
#         ...,
#         [  0.       ,   0.       ,   0.       , 220.8533   ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 224.47542  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 158.91235  ,
#            0.       ]],
#
#        [[  0.       ,   0.       ,   0.       , 180.22348  ,
#           51.681744 ],
#         [  0.       ,   0.       ,   0.       , 190.83084  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 197.49484  ,
#            0.       ],
#         ...,
#         [  0.       ,   0.       ,   0.       , 178.02077  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 225.10152  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 153.83652  ,
#            0.       ]],
#
#        [[  0.       ,   0.       ,   0.       ,  63.203247 ,
#           19.79493  ],
#         [  0.       ,   0.       ,   0.       , 136.59235  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 138.7725   ,
#            0.       ],
#         ...,
#         [  0.       ,   0.       ,   0.       , 137.98491  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 140.40143  ,
#            0.       ],
#         [  0.       ,   0.       ,   0.       , 169.50671  ,
#            0.       ]]], dtype=float32)

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# # 6. Flatten layer를 활용하여 vector로 만들기

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='linear', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model = Model(inputs=model.input, outputs=model.output)

# %%
model.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16_input (InputLayer  [(None, 56, 56, 3)]      0
#  )
#
#  conv2d_16 (Conv2D)          (None, 56, 56, 5)         140
#
#  flatten (Flatten)           (None, 15680)             0
#
# =================================================================
# Total params: 140
# Trainable params: 140
# Non-trainable params: 0
# _________________________________________________________________

# %%
Predicted = model.predict(Train_x[:1])
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
Predicted.shape
# Out:
# (1, 15680)

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# # 7. Fine-tuning이 가능한 모델 구현하기

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='linear', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='linear'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.summary()
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18_input (InputLayer  [(None, 56, 56, 3)]      0
#  )
#
#  conv2d_18 (Conv2D)          (None, 56, 56, 5)         140
#
#  flatten_2 (Flatten)         (None, 15680)             0
#
#  dense_1 (Dense)             (None, 1)                 15681
#
# =================================================================
# Total params: 15,821
# Trainable params: 15,821
# Non-trainable params: 0
# _________________________________________________________________

# %%
Predicted = model.predict(Train_x[:1])
Predicted.shape
# Out:
# 1/1 [==============================] - 0s 66ms/step
# (1, 1)

# %%
print(Predicted)
# Out:
# [[-134.16959]]

# %% [markdown]
# ## fine tuning

# %% [markdown]
# Loss: Mean Squared Error

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=Train_x, y=Train_y, epochs=50)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 2s 72ms/step - loss: 0.0973
# Epoch 2/50
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0350
# Epoch 3/50
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0176
# Epoch 4/50
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0121
# Epoch 5/50
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0146
# Epoch 6/50
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0134
# Epoch 7/50
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0038
# Epoch 8/50
# 17/17 [==============================] - 1s 77ms/step - loss: 0.0036
# Epoch 9/50
# 17/17 [==============================] - 1s 77ms/step - loss: 8.3241e-04
# Epoch 10/50
# 17/17 [==============================] - 1s 77ms/step - loss: 6.3358e-04
# Epoch 11/50
# 17/17 [==============================] - 1s 78ms/step - loss: 3.9238e-04
# Epoch 12/50
# 17/17 [==============================] - 1s 77ms/step - loss: 2.6578e-04
# Epoch 13/50
# 17/17 [==============================] - 1s 80ms/step - loss: 1.8165e-04
# Epoch 14/50
# 17/17 [==============================] - 1s 83ms/step - loss: 1.6460e-04
# Epoch 15/50
# 17/17 [==============================] - 1s 80ms/step - loss: 1.3501e-04
# Epoch 16/50
# 17/17 [==============================] - 1s 79ms/step - loss: 1.1736e-04
# Epoch 17/50
# 17/17 [==============================] - 1s 86ms/step - loss: 1.0983e-04
# Epoch 18/50
# 17/17 [==============================] - 2s 89ms/step - loss: 9.1943e-05
# Epoch 19/50
# 17/17 [==============================] - 1s 80ms/step - loss: 8.6717e-05
# Epoch 20/50
# 17/17 [==============================] - 1s 78ms/step - loss: 7.6574e-05
# Epoch 21/50
# 17/17 [==============================] - 1s 80ms/step - loss: 7.0237e-05
# Epoch 22/50
# 17/17 [==============================] - 1s 78ms/step - loss: 6.3947e-05
# Epoch 23/50
# 17/17 [==============================] - 1s 79ms/step - loss: 6.0136e-05
# Epoch 24/50
# 17/17 [==============================] - 1s 87ms/step - loss: 5.4595e-05
# Epoch 25/50
# 17/17 [==============================] - 2s 88ms/step - loss: 5.1281e-05
# Epoch 26/50
# 17/17 [==============================] - 1s 86ms/step - loss: 4.7828e-05
# Epoch 27/50
# 17/17 [==============================] - 1s 83ms/step - loss: 4.4754e-05
# Epoch 28/50
# 17/17 [==============================] - 1s 79ms/step - loss: 4.1524e-05
# Epoch 29/50
# 17/17 [==============================] - 1s 78ms/step - loss: 3.8909e-05
# Epoch 30/50
# 17/17 [==============================] - 1s 79ms/step - loss: 3.6488e-05
# Epoch 31/50
# 17/17 [==============================] - 1s 80ms/step - loss: 3.4587e-05
# Epoch 32/50
# 17/17 [==============================] - 1s 81ms/step - loss: 3.2779e-05
# Epoch 33/50
# 17/17 [==============================] - 1s 83ms/step - loss: 3.0640e-05
# Epoch 34/50
# 17/17 [==============================] - 1s 80ms/step - loss: 2.9614e-05
# Epoch 35/50
# 17/17 [==============================] - 1s 83ms/step - loss: 2.7687e-05
# Epoch 36/50
# 17/17 [==============================] - 1s 81ms/step - loss: 2.6362e-05
# Epoch 37/50
# 17/17 [==============================] - 1s 81ms/step - loss: 2.5100e-05
# Epoch 38/50
# 17/17 [==============================] - 1s 79ms/step - loss: 2.3884e-05
# Epoch 39/50
# 17/17 [==============================] - 1s 78ms/step - loss: 2.3148e-05
# Epoch 40/50
# 17/17 [==============================] - 1s 77ms/step - loss: 2.1921e-05
# Epoch 41/50
# 17/17 [==============================] - 1s 81ms/step - loss: 2.0969e-05
# Epoch 42/50
# 17/17 [==============================] - 1s 81ms/step - loss: 1.9913e-05
# Epoch 43/50
# 17/17 [==============================] - 1s 77ms/step - loss: 1.9008e-05
# Epoch 44/50
# 17/17 [==============================] - 1s 79ms/step - loss: 1.8411e-05
# Epoch 45/50
# 17/17 [==============================] - 1s 78ms/step - loss: 1.7481e-05
# Epoch 46/50
# 17/17 [==============================] - 1s 78ms/step - loss: 1.6868e-05
# Epoch 47/50
# 17/17 [==============================] - 1s 81ms/step - loss: 1.6217e-05
# Epoch 48/50
# 17/17 [==============================] - 2s 90ms/step - loss: 1.5521e-05
# Epoch 49/50
# 17/17 [==============================] - 1s 78ms/step - loss: 1.5045e-05
# Epoch 50/50
# 17/17 [==============================] - 1s 81ms/step - loss: 1.4460e-05

# %% [markdown]
# Test data 전체에 prediction 수행해보기

# %%
Predicted = model.predict(Test_x)
# Out:
# 2/2 [==============================] - 0s 31ms/step

# %%
Predicted[:10]
# Out:
# array([[1.2012947e-05],
#        [8.0970415e-07],
#        [2.8854769e-02],
#        [2.8817344e-03],
#        [3.5552369e-04],
#        [9.9695784e-01],
#        [9.6208987e-06],
#        [2.3297574e-05],
#        [1.2580657e-01],
#        [1.2616785e-03]], dtype=float32)

# %%
CheckSame = [Pred == Label for Pred, Label in zip(Predicted>0.5, Test_y == 1)]
pd.Series(CheckSame).value_counts()

# 정확도: 34 / 60 = 56%
# Out:
# [True]     48
# [False]    12
# dtype: int64

# %% [markdown]
# Loss: Mean Squared Error 는 regression에 사용하는 것.<br>
# -> Cross-entropy를 적용하여야함
#
# activation function을 Sigmoid function을 활용하여, output을 0~1 사이로 바꿔줘야함<br>

# %% [markdown]
# <br><br><br>
# model optimizer에 대한 confitures 확인하기

# %%
model.optimizer.get_config()
# Out:
# {'name': 'Adam',
#  'learning_rate': 0.001,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %% [markdown]
# <br><br><br><br><br><br><br>

# %% [markdown]
# # 8. Sigmoid function & CrossEntropy를 활용한 classification

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='linear', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')

# %%
model.fit(x=Train_x, y=Train_y, epochs=50)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 1s 16ms/step - loss: 250.5344
# Epoch 2/50
# 17/17 [==============================] - 0s 14ms/step - loss: 20.9545
# Epoch 3/50
# 17/17 [==============================] - 0s 15ms/step - loss: 8.8575
# Epoch 4/50
# 17/17 [==============================] - 0s 14ms/step - loss: 7.6113
# Epoch 5/50
# 17/17 [==============================] - 0s 16ms/step - loss: 6.8681
# Epoch 6/50
# 17/17 [==============================] - 0s 14ms/step - loss: 4.8451
# Epoch 7/50
# 17/17 [==============================] - 0s 15ms/step - loss: 4.5115
# Epoch 8/50
# 17/17 [==============================] - 0s 14ms/step - loss: 2.7578
# Epoch 9/50
# 17/17 [==============================] - 0s 16ms/step - loss: 7.0324
# Epoch 10/50
# 17/17 [==============================] - 0s 14ms/step - loss: 14.1686
# Epoch 11/50
# 17/17 [==============================] - 0s 14ms/step - loss: 5.6454
# Epoch 12/50
# 17/17 [==============================] - 0s 15ms/step - loss: 2.5730
# Epoch 13/50
# 17/17 [==============================] - 0s 14ms/step - loss: 1.2551
# Epoch 14/50
# 17/17 [==============================] - 0s 14ms/step - loss: 0.9110
# Epoch 15/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.9115
# Epoch 16/50
# 17/17 [==============================] - 0s 15ms/step - loss: 1.0157
# Epoch 17/50
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5294
# Epoch 18/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4174
# Epoch 19/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3481
# Epoch 20/50
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2477
# Epoch 21/50
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1970
# Epoch 22/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4906
# Epoch 23/50
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1422
# Epoch 24/50
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1122
# Epoch 25/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1179
# Epoch 26/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0721
# Epoch 27/50
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0371
# Epoch 28/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0497
# Epoch 29/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0228
# Epoch 30/50
# 17/17 [==============================] - 0s 15ms/step - loss: 4.8491e-04
# Epoch 31/50
# 17/17 [==============================] - 0s 15ms/step - loss: 5.7615e-04
# Epoch 32/50
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 33/50
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 34/50
# 17/17 [==============================] - 0s 15ms/step - loss: 5.4164e-04
# Epoch 35/50
# 17/17 [==============================] - 0s 14ms/step - loss: 4.4886e-04
# Epoch 36/50
# 17/17 [==============================] - 0s 14ms/step - loss: 7.1913e-05
# Epoch 37/50
# 17/17 [==============================] - 0s 15ms/step - loss: 4.2169e-05
# Epoch 38/50
# 17/17 [==============================] - 0s 14ms/step - loss: 2.2620e-05
# Epoch 39/50
# 17/17 [==============================] - 0s 15ms/step - loss: 2.1673e-05
# Epoch 40/50
# 17/17 [==============================] - 0s 15ms/step - loss: 2.0644e-05
# Epoch 41/50
# 17/17 [==============================] - 0s 14ms/step - loss: 2.0058e-05
# Epoch 42/50
# 17/17 [==============================] - 0s 14ms/step - loss: 1.9676e-05
# Epoch 43/50
# 17/17 [==============================] - 0s 15ms/step - loss: 1.9697e-05
# Epoch 44/50
# 17/17 [==============================] - 0s 14ms/step - loss: 1.9271e-05
# Epoch 45/50
# 17/17 [==============================] - 0s 14ms/step - loss: 1.9071e-05
# Epoch 46/50
# 17/17 [==============================] - 0s 14ms/step - loss: 1.9177e-05
# Epoch 47/50
# 17/17 [==============================] - 0s 15ms/step - loss: 1.9129e-05
# Epoch 48/50
# 17/17 [==============================] - 0s 14ms/step - loss: 1.8656e-05
# Epoch 49/50
# 17/17 [==============================] - 0s 15ms/step - loss: 1.8522e-05
# Epoch 50/50
# 17/17 [==============================] - 0s 15ms/step - loss: 1.8424e-05

# %%
Predicted = model.predict(Test_x)
# Out:
# 2/2 [==============================] - 0s 26ms/step

# %%
Predicted[:10]
# Out:
# array([[8.3496540e-13],
#        [1.9556075e-05],
#        [1.3581209e-24],
#        [1.9891684e-24],
#        [1.8842308e-12],
#        [1.4586280e-01],
#        [1.6021579e-23],
#        [2.5465990e-27],
#        [1.0103875e-06],
#        [1.4749410e-16]], dtype=float32)

# %%
CheckSame = [Pred == Label for Pred, Label in zip(Predicted>0.5, Test_y == 1)]
pd.Series(CheckSame).value_counts()

# 정확도: 52 / 60 = 86.67%
# Out:
# [True]     52
# [False]     8
# dtype: int64

# %% [markdown]
# # 9.CNN Wide 하게 구현하기

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(30, (3, 3), activation='linear', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')

# %%
model.fit(x=Train_x, y=Train_y, epochs=50)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 1s 26ms/step - loss: 713.9815
# Epoch 2/50
# 17/17 [==============================] - 0s 25ms/step - loss: 117.7876
# Epoch 3/50
# 17/17 [==============================] - 0s 22ms/step - loss: 27.6652
# Epoch 4/50
# 17/17 [==============================] - 0s 23ms/step - loss: 12.0138
# Epoch 5/50
# 17/17 [==============================] - 0s 26ms/step - loss: 4.4631
# Epoch 6/50
# 17/17 [==============================] - 0s 22ms/step - loss: 2.4879
# Epoch 7/50
# 17/17 [==============================] - 0s 25ms/step - loss: 3.2968
# Epoch 8/50
# 17/17 [==============================] - 0s 26ms/step - loss: 1.6371
# Epoch 9/50
# 17/17 [==============================] - 0s 28ms/step - loss: 0.9021
# Epoch 10/50
# 17/17 [==============================] - 0s 23ms/step - loss: 0.1263
# Epoch 11/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0460
# Epoch 12/50
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0144
# Epoch 13/50
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0012
# Epoch 14/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0016
# Epoch 15/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.1733
# Epoch 16/50
# 17/17 [==============================] - 0s 26ms/step - loss: 0.3608
# Epoch 17/50
# 17/17 [==============================] - 0s 26ms/step - loss: 0.0719
# Epoch 18/50
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0882
# Epoch 19/50
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0891
# Epoch 20/50
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2777
# Epoch 21/50
# 17/17 [==============================] - 0s 25ms/step - loss: 0.1141
# Epoch 22/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0594
# Epoch 23/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0372
# Epoch 24/50
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0197
# Epoch 25/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0282
# Epoch 26/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0039
# Epoch 27/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0529
# Epoch 28/50
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0283
# Epoch 29/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0219
# Epoch 30/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0046
# Epoch 31/50
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2531
# Epoch 32/50
# 17/17 [==============================] - 0s 25ms/step - loss: 1.6018
# Epoch 33/50
# 17/17 [==============================] - 0s 22ms/step - loss: 0.7647
# Epoch 34/50
# 17/17 [==============================] - 0s 27ms/step - loss: 1.3559
# Epoch 35/50
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2369
# Epoch 36/50
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2236
# Epoch 37/50
# 17/17 [==============================] - 0s 26ms/step - loss: 0.0434
# Epoch 38/50
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0257
# Epoch 39/50
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0106
# Epoch 40/50
# 17/17 [==============================] - 0s 22ms/step - loss: 2.3871e-05
# Epoch 41/50
# 17/17 [==============================] - 0s 22ms/step - loss: 1.5170e-04
# Epoch 42/50
# 17/17 [==============================] - 0s 24ms/step - loss: 5.7584e-05
# Epoch 43/50
# 17/17 [==============================] - 0s 22ms/step - loss: 1.0969e-05
# Epoch 44/50
# 17/17 [==============================] - 0s 22ms/step - loss: 6.7336e-06
# Epoch 45/50
# 17/17 [==============================] - 0s 21ms/step - loss: 5.6412e-06
# Epoch 46/50
# 17/17 [==============================] - 0s 22ms/step - loss: 5.2035e-06
# Epoch 47/50
# 17/17 [==============================] - 0s 24ms/step - loss: 4.7267e-06
# Epoch 48/50
# 17/17 [==============================] - 0s 22ms/step - loss: 4.3562e-06
# Epoch 49/50
# 17/17 [==============================] - 0s 23ms/step - loss: 3.9816e-06
# Epoch 50/50
# 17/17 [==============================] - 0s 20ms/step - loss: 3.7580e-06

# %%
Predicted = model.predict(Test_x)
# Out:
# 2/2 [==============================] - 0s 20ms/step

# %%
CheckSame = [Pred == Label for Pred, Label in zip(Predicted>0.5, Test_y == 1)]
pd.Series(CheckSame).value_counts()

# 정확도: 52 / 60 = 86.67%
# Out:
# [True]     52
# [False]     8
# dtype: int64

# %% [markdown]
# # 10.CNN Deep 하게 구현하기

# %% [markdown]
# Activation function에 relu를 사용해본다.

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.summary()
# Out:
# Model: "model_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_29_input (InputLayer  [(None, 56, 56, 3)]      0
#  )
#
#  conv2d_29 (Conv2D)          (None, 56, 56, 5)         140
#
#  conv2d_30 (Conv2D)          (None, 56, 56, 5)         230
#
#  conv2d_31 (Conv2D)          (None, 56, 56, 5)         230
#
#  conv2d_32 (Conv2D)          (None, 56, 56, 5)         230
#
#  flatten_7 (Flatten)         (None, 15680)             0
#
#  dense_6 (Dense)             (None, 1)                 15681
#
# =================================================================
# Total params: 16,511
# Trainable params: 16,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')

# %%
model.fit(x=Train_x, y=Train_y, epochs=15)
# Out:
# Epoch 1/15
# 17/17 [==============================] - 2s 60ms/step - loss: 1.6814
# Epoch 2/15
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6683
# Epoch 3/15
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4844
# Epoch 4/15
# 17/17 [==============================] - 1s 60ms/step - loss: 0.3980
# Epoch 5/15
# 17/17 [==============================] - 1s 63ms/step - loss: 0.3345
# Epoch 6/15
# 17/17 [==============================] - 1s 66ms/step - loss: 0.2801
# Epoch 7/15
# 17/17 [==============================] - 1s 65ms/step - loss: 0.2171
# Epoch 8/15
# 17/17 [==============================] - 1s 65ms/step - loss: 0.1509
# Epoch 9/15
# 17/17 [==============================] - 1s 75ms/step - loss: 0.1064
# Epoch 10/15
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0746
# Epoch 11/15
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0440
# Epoch 12/15
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0309
# Epoch 13/15
# 17/17 [==============================] - 1s 67ms/step - loss: 0.0208
# Epoch 14/15
# 17/17 [==============================] - 1s 69ms/step - loss: 0.0152
# Epoch 15/15
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0098

# %%
Predicted = model.predict(Test_x)

CheckSame = [Pred == Label for Pred, Label in zip(Predicted>0.5, Test_y == 1)]
pd.Series(CheckSame).value_counts()

# 정확도: 51 / 60 = 85%
# Out:
# 2/2 [==============================] - 0s 26ms/step
# [True]     51
# [False]     9
# dtype: int64

# %% [markdown]
# <br><br><br><br>
# # 11. Test Data Set에 fit 해보기

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')

# %%
model.fit(x=Train_x, y=Train_y, epochs=15, validation_data=(Test_x, Test_y))
# Out:
# Epoch 1/15
# 17/17 [==============================] - 2s 80ms/step - loss: 15.2580 - val_loss: 3.0012
# Epoch 2/15
# 17/17 [==============================] - 1s 61ms/step - loss: 1.3819 - val_loss: 0.7340
# Epoch 3/15
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6320 - val_loss: 0.5432
# Epoch 4/15
# 17/17 [==============================] - 1s 60ms/step - loss: 0.5763 - val_loss: 0.5005
# Epoch 5/15
# 17/17 [==============================] - 1s 60ms/step - loss: 0.5356 - val_loss: 0.4643
# Epoch 6/15
# 17/17 [==============================] - 1s 61ms/step - loss: 0.5008 - val_loss: 0.4338
# Epoch 7/15
# 17/17 [==============================] - 1s 61ms/step - loss: 0.4742 - val_loss: 0.4181
# Epoch 8/15
# 17/17 [==============================] - 1s 61ms/step - loss: 0.4481 - val_loss: 0.3839
# Epoch 9/15
# 17/17 [==============================] - 1s 63ms/step - loss: 0.4238 - val_loss: 0.3584
# Epoch 10/15
# 17/17 [==============================] - 1s 65ms/step - loss: 0.4017 - val_loss: 0.3612
# Epoch 11/15
# 17/17 [==============================] - 1s 63ms/step - loss: 0.3965 - val_loss: 0.4125
# Epoch 12/15
# 17/17 [==============================] - 1s 62ms/step - loss: 0.3967 - val_loss: 0.3515
# Epoch 13/15
# 17/17 [==============================] - 1s 63ms/step - loss: 0.3628 - val_loss: 0.3169
# Epoch 14/15
# 17/17 [==============================] - 1s 64ms/step - loss: 0.3422 - val_loss: 0.3205
# Epoch 15/15
# 17/17 [==============================] - 1s 64ms/step - loss: 0.3270 - val_loss: 0.2876

# %%
Predicted = model.predict(Test_x)

CheckSame = [Pred == Label for Pred, Label in zip(Predicted>0.5, Test_y == 1)]
pd.Series(CheckSame).value_counts()

# 정확도: 55 / 60 = 85%
# Out:
# 2/2 [==============================] - 0s 47ms/step
# [True]     55
# [False]     5
# dtype: int64

# %% [markdown]
# validation data는 학습에 포함되는 데이터가 아니므로, weight에 영향을 주지 않는다.<br>
# 다만, epoch을 돌면서 validation set에 성능이 얼마나 잘 나오는지 확인할 수 있다.

# %% [markdown]
# <br><br><br><br><br>
# # 12. Metric에 accuracy 추가해보기

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc', 'mse', 'mae'])

# %%
model.fit(x=Train_x, y=Train_y, epochs=15, validation_data=(Test_x, Test_y))
# Out:
# Epoch 1/15
# 17/17 [==============================] - 2s 79ms/step - loss: 6.9629 - acc: 0.5093 - mse: 0.4505 - mae: 0.4865 - val_loss: 0.7517 - val_acc: 0.6500 - val_mse: 0.2513 - val_mae: 0.4234
# Epoch 2/15
# 17/17 [==============================] - 1s 60ms/step - loss: 0.7415 - acc: 0.5981 - mse: 0.2521 - mae: 0.4292 - val_loss: 0.5071 - val_acc: 0.7500 - val_mse: 0.1656 - val_mae: 0.3677
# Epoch 3/15
# 17/17 [==============================] - 1s 62ms/step - loss: 0.5103 - acc: 0.7611 - mse: 0.1685 - mae: 0.3681 - val_loss: 0.4200 - val_acc: 0.8667 - val_mse: 0.1285 - val_mae: 0.3165
# Epoch 4/15
# 17/17 [==============================] - 1s 61ms/step - loss: 0.4382 - acc: 0.8056 - mse: 0.1409 - mae: 0.3077 - val_loss: 0.3420 - val_acc: 0.8500 - val_mse: 0.1021 - val_mae: 0.2535
# Epoch 5/15
# 17/17 [==============================] - 1s 61ms/step - loss: 0.3962 - acc: 0.8333 - mse: 0.1254 - mae: 0.2661 - val_loss: 0.2997 - val_acc: 0.9000 - val_mse: 0.0875 - val_mae: 0.2189
# Epoch 6/15
# 17/17 [==============================] - 1s 62ms/step - loss: 0.3462 - acc: 0.8519 - mse: 0.1063 - mae: 0.2280 - val_loss: 0.2761 - val_acc: 0.9000 - val_mse: 0.0799 - val_mae: 0.1930
# Epoch 7/15
# 17/17 [==============================] - 1s 60ms/step - loss: 0.3034 - acc: 0.8796 - mse: 0.0914 - mae: 0.2007 - val_loss: 0.2714 - val_acc: 0.9167 - val_mse: 0.0782 - val_mae: 0.1901
# Epoch 8/15
# 17/17 [==============================] - 1s 62ms/step - loss: 0.2758 - acc: 0.8963 - mse: 0.0825 - mae: 0.1845 - val_loss: 0.2647 - val_acc: 0.8500 - val_mse: 0.0835 - val_mae: 0.1738
# Epoch 9/15
# 17/17 [==============================] - 1s 63ms/step - loss: 0.2427 - acc: 0.9185 - mse: 0.0716 - mae: 0.1664 - val_loss: 0.2384 - val_acc: 0.9167 - val_mse: 0.0709 - val_mae: 0.1600
# Epoch 10/15
# 17/17 [==============================] - 1s 62ms/step - loss: 0.2170 - acc: 0.9204 - mse: 0.0629 - mae: 0.1536 - val_loss: 0.2391 - val_acc: 0.9333 - val_mse: 0.0681 - val_mae: 0.1590
# Epoch 11/15
# 17/17 [==============================] - 1s 66ms/step - loss: 0.1982 - acc: 0.9167 - mse: 0.0573 - mae: 0.1409 - val_loss: 0.2303 - val_acc: 0.9333 - val_mse: 0.0662 - val_mae: 0.1555
# Epoch 12/15
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1682 - acc: 0.9500 - mse: 0.0455 - mae: 0.1231 - val_loss: 0.2549 - val_acc: 0.8500 - val_mse: 0.0831 - val_mae: 0.1628
# Epoch 13/15
# 17/17 [==============================] - 1s 66ms/step - loss: 0.1610 - acc: 0.9407 - mse: 0.0451 - mae: 0.1154 - val_loss: 0.2035 - val_acc: 0.9333 - val_mse: 0.0616 - val_mae: 0.1374
# Epoch 14/15
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1312 - acc: 0.9648 - mse: 0.0338 - mae: 0.0956 - val_loss: 0.2168 - val_acc: 0.9167 - val_mse: 0.0656 - val_mae: 0.1407
# Epoch 15/15
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1193 - acc: 0.9685 - mse: 0.0304 - mae: 0.0886 - val_loss: 0.1893 - val_acc: 0.9333 - val_mse: 0.0566 - val_mae: 0.1301

# %% [markdown]
# Test set을 validation으로 활용하면, 가장 잘 나온 모델을 선택할 수 있음<br>
# 사실 이것은 Test set에 대한 fitting 이므로, 자제해야함<br>
# => Validation set을 따로 구성해야하는 이유

# %% [markdown]
# <br><br><br><br><br>
# # 13. CallBack 함수, CheckPoint 활용하기

# %%
# CheckPoint: Epoch 마다 validation 성능을 검증하여, best performance 일 경우 저장
CP = ModelCheckpoint(filepath='MODEL/{epoch:03d}-{loss:.4f}-{acc:.4f}-{val_loss:.4f}-{val_acc:.4f}.hdf5',
            monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.fit(x=Train_x, y=Train_y, epochs=50, validation_data=(Test_x, Test_y), callbacks=[CP])
# Out:
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 6.6765 - acc: 0.5185
# Epoch 1: val_acc improved from -inf to 0.55000, saving model to MODEL\001-6.6765-0.5185-0.6745-0.5500.hdf5
# 17/17 [==============================] - 2s 91ms/step - loss: 6.6765 - acc: 0.5185 - val_loss: 0.6745 - val_acc: 0.5500
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss: 0.7563 - acc: 0.5926
# Epoch 2: val_acc improved from 0.55000 to 0.65000, saving model to MODEL\002-0.7563-0.5926-0.6196-0.6500.hdf5
# 17/17 [==============================] - 1s 86ms/step - loss: 0.7563 - acc: 0.5926 - val_loss: 0.6196 - val_acc: 0.6500
# Epoch 3/50
# 17/17 [==============================] - ETA: 0s - loss: 0.6517 - acc: 0.6593
# Epoch 3: val_acc improved from 0.65000 to 0.68333, saving model to MODEL\003-0.6517-0.6593-0.5892-0.6833.hdf5
# 17/17 [==============================] - 1s 79ms/step - loss: 0.6517 - acc: 0.6593 - val_loss: 0.5892 - val_acc: 0.6833
# Epoch 4/50
# 17/17 [==============================] - ETA: 0s - loss: 0.6142 - acc: 0.6630
# Epoch 4: val_acc improved from 0.68333 to 0.73333, saving model to MODEL\004-0.6142-0.6630-0.5509-0.7333.hdf5
# 17/17 [==============================] - 1s 81ms/step - loss: 0.6142 - acc: 0.6630 - val_loss: 0.5509 - val_acc: 0.7333
# Epoch 5/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5934 - acc: 0.6870
# Epoch 5: val_acc improved from 0.73333 to 0.75000, saving model to MODEL\005-0.5934-0.6870-0.5528-0.7500.hdf5
# 17/17 [==============================] - 1s 80ms/step - loss: 0.5934 - acc: 0.6870 - val_loss: 0.5528 - val_acc: 0.7500
# Epoch 6/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5379 - acc: 0.7315
# Epoch 6: val_acc improved from 0.75000 to 0.76667, saving model to MODEL\006-0.5379-0.7315-0.4652-0.7667.hdf5
# 17/17 [==============================] - 1s 83ms/step - loss: 0.5379 - acc: 0.7315 - val_loss: 0.4652 - val_acc: 0.7667
# Epoch 7/50
# 17/17 [==============================] - ETA: 0s - loss: 0.
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0072 - acc: 1.0000
# Epoch 49: val_acc did not improve from 0.90000
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0072 - acc: 1.0000 - val_loss: 0.8565 - val_acc: 0.8833
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0070 - acc: 1.0000
# Epoch 50: val_acc did not improve from 0.90000
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0070 - acc: 1.0000 - val_loss: 0.8729 - val_acc: 0.8833

# %%
MoelWeights = os.listdir('MODEL')
MoelWeights
# Out:
# ['001-6.6765-0.5185-0.6745-0.5500.hdf5',
#  '002-0.7563-0.5926-0.6196-0.6500.hdf5',
#  '003-0.6517-0.6593-0.5892-0.6833.hdf5',
#  '004-0.6142-0.6630-0.5509-0.7333.hdf5',
#  '005-0.5934-0.6870-0.5528-0.7500.hdf5',
#  '006-0.5379-0.7315-0.4652-0.7667.hdf5',
#  '007-0.4856-0.7574-0.4038-0.8000.hdf5',
#  '010-0.3915-0.8259-0.3520-0.8333.hdf5',
#  '011-0.2849-0.8556-0.2873-0.8500.hdf5',
#  '013-0.2554-0.8870-0.2922-0.8667.hdf5',
#  '016-0.1619-0.9296-0.2877-0.9000.hdf5']

# %%
BestModel = MoelWeights[ len(MoelWeights) -1 ]
BestModel
# Out:
# '016-0.1619-0.9296-0.2877-0.9000.hdf5'

# %%
model.load_weights('MODEL/' + BestModel)

# %%
Predicted = model.predict(Test_x)

CheckSame = [Pred == Label for Pred, Label in zip(Predicted>0.5, Test_y == 1)]
pd.Series(CheckSame).value_counts()

# 정확도: 54 / 60 = 90%
# Out:
# 2/2 [==============================] - 0s 32ms/step
# [True]     54
# [False]     6
# dtype: int64

# %% [markdown]
# <br><br><br><br><br>
# # 14. CallBack 함수, CheckPoint & Reduce LR (Learning Rate) 활용하기

# %% [markdown]
# MODEL/ 안에 저장된 weight 파일들은 다시 삭제

# %%
# CheckPoint: Epoch 마다 validation 성능을 검증하여, best performance 일 경우 저장
CP = ModelCheckpoint(filepath='MODEL/{epoch:03d}-{loss:.4f}-{acc:.4f}-{val_loss:.4f}-{val_acc:.4f}.hdf5',
            monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# Learning Rate 줄여나가기
LR = ReduceLROnPlateau(monitor='val_loss',factor=0.8,patience=2, verbose=1, min_lr=1e-8)

CALLBACK = [CP, LR]

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.fit(x=Train_x, y=Train_y, epochs=50, validation_data=(Test_x, Test_y), callbacks=CALLBACK)
# Out:
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 7.6878 - acc: 0.4926
# Epoch 1: val_acc improved from -inf to 0.61667, saving model to MODEL\001-7.6878-0.4926-0.9044-0.6167.hdf5
# 17/17 [==============================] - 2s 92ms/step - loss: 7.6878 - acc: 0.4926 - val_loss: 0.9044 - val_acc: 0.6167 - lr: 0.0010
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss: 0.6727 - acc: 0.6519
# Epoch 2: val_acc improved from 0.61667 to 0.75000, saving model to MODEL\002-0.6727-0.6519-0.5072-0.7500.hdf5
# 17/17 [==============================] - 1s 82ms/step - loss: 0.6727 - acc: 0.6519 - val_loss: 0.5072 - val_acc: 0.7500 - lr: 0.0010
# Epoch 3/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5322 - acc: 0.7537
# Epoch 3: val_acc did not improve from 0.75000
# 17/17 [==============================] - 1s 78ms/step - loss: 0.5322 - acc: 0.7537 - val_loss: 0.5022 - val_acc: 0.7333 - lr: 0.0010
# Epoch 4/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4613 - acc: 0.8093
# Epoch 4: val_acc improved from 0.75000 to 0.78333, saving model to MODEL\004-0.4613-0.8093-0.4430-0.7833.hdf5
# 17/17 [==============================] - 1s 80ms/step - loss: 0.4613 - acc: 0.8093 - val_loss: 0.4430 - val_acc: 0.7833 - lr: 0.0010
# Epoch 5/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3958 - acc: 0.8519
# Epoch 5: val_acc improved from 0.78333 to 0.83333, saving model to MODEL\005-0.3958-0.8519-0.4156-0.8333.hdf5
# 17/17 [==============================] - 1s 80ms/step - loss: 0.3958 - acc: 0.8519 - val_loss: 0.4156 - val_acc: 0.8333 - lr: 0.0010
# Epoch 6/50
# 17/17 [==============================] - ETA: 0s - loss: 0.
val_acc did not improve from 0.83333
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0139 - acc: 0.9981 - val_loss: 0.7758 - val_acc: 0.7833 - lr: 1.8014e-05
# Epoch 46/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0138 - acc: 0.9981
# Epoch 46: val_acc did not improve from 0.83333
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0138 - acc: 0.9981 - val_loss: 0.7804 - val_acc: 0.7833 - lr: 1.8014e-05
# Epoch 47/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0137 - acc: 0.9981
# Epoch 47: val_acc did not improve from 0.83333
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0137 - acc: 0.9981 - val_loss: 0.7821 - val_acc: 0.7833 - lr: 1.4412e-05
# Epoch 48/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0136 - acc: 0.9981
# Epoch 48: val_acc did not improve from 0.83333
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0136 - acc: 0.9981 - val_loss: 0.7808 - val_acc: 0.7833 - lr: 1.4412e-05
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0136 - acc: 0.9981
# Epoch 49: val_acc did not improve from 0.83333
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0136 - acc: 0.9981 - val_loss: 0.7819 - val_acc: 0.7833 - lr: 1.1529e-05
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0135 - acc: 0.9981
# Epoch 50: val_acc did not improve from 0.83333
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0135 - acc: 0.9981 - val_loss: 0.7837 - val_acc: 0.7833 - lr: 1.1529e-05

# %%
model.optimizer.get_config()
# Out:
# {'name': 'Adam',
#  'learning_rate': 9.223373e-06,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %% [markdown]
# ## tensorboard 사용하기

# %%
# CheckPoint: Epoch 마다 validation 성능을 검증하여, best performance 일 경우 저장
CP = ModelCheckpoint(filepath='MODEL/{epoch:03d}-{loss:.4f}-{acc:.4f}-{val_loss:.4f}-{val_acc:.4f}.hdf5',
            monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# tensorboard
TB = TensorBoard(log_dir='logs', write_graph=True, write_images=True)

# Learning Rate 줄여나가기
LR = ReduceLROnPlateau(monitor='val_loss',factor=0.8,patience=2, verbose=1, min_lr=1e-8)

CALLBACK = [CP, TB, LR]

# %%
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.fit(x=Train_x, y=Train_y, epochs=50, validation_data=(Test_x, Test_y), callbacks=CALLBACK)
# Out:
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 20.0980 - acc: 0.4833
# Epoch 1: val_acc improved from -inf to 0.53333, saving model to MODEL\001-20.0980-0.4833-3.3947-0.5333.hdf5
# 17/17 [==============================] - 2s 79ms/step - loss: 20.0980 - acc: 0.4833 - val_loss: 3.3947 - val_acc: 0.5333 - lr: 0.0010
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss: 1.1769 - acc: 0.5944
# Epoch 2: val_acc improved from 0.53333 to 0.60000, saving model to MODEL\002-1.1769-0.5944-0.5780-0.6000.hdf5
# 17/17 [==============================] - 1s 65ms/step - loss: 1.1769 - acc: 0.5944 - val_loss: 0.5780 - val_acc: 0.6000 - lr: 0.0010
# Epoch 3/50
# 17/17 [==============================] - ETA: 0s - loss: 0.6310 - acc: 0.6667
# Epoch 3: val_acc improved from 0.60000 to 0.70000, saving model to MODEL\003-0.6310-0.6667-0.4935-0.7000.hdf5
# 17/17 [==============================] - 1s 69ms/step - loss: 0.6310 - acc: 0.6667 - val_loss: 0.4935 - val_acc: 0.7000 - lr: 0.0010
# Epoch 4/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4926 - acc: 0.7667
# Epoch 4: val_acc improved from 0.70000 to 0.80000, saving model to MODEL\004-0.4926-0.7667-0.4327-0.8000.hdf5
# 17/17 [==============================] - 1s 71ms/step - loss: 0.4926 - acc: 0.7667 - val_loss: 0.4327 - val_acc: 0.8000 - lr: 0.0010
# Epoch 5/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4071 - acc: 0.8167
# Epoch 5: val_acc improved from 0.80000 to 0.81667, saving model to MODEL\005-0.4071-0.8167-0.3959-0.8167.hdf5
# 17/17 [==============================] - 1s 65ms/step - loss: 0.4071 - acc: 0.8167 - val_loss: 0.3959 - val_acc: 0.8167 - lr: 0.0010
# Epoch 6/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3559 - acc: 0.8444
# Epoch 6: val_acc did not improve from 0.81667
# 17/17 [==============================] - 1s 64ms/step - loss: 0.3559 - acc: 0.8444 - val_loss: 0.3954 - val_acc: 0.8167 - lr: 0.0010
# Epoch 7/50
# 16/17 [===========================>..] - ETA: 0s - loss: 0.3661 - acc: 0.8477
# Epoch 7: val_acc did not improve from 0.81667
# 17/17 [==============================] - 1s 62ms/step - loss: 0.3750 - acc: 0.8407 - val_loss: 0.4522 - val_acc: 0.7667 - lr: 0.0010
# Epoch 8/50
# 17/17 [==============================] - ETA: 0s - loss: 0.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0759 - acc: 0.9870 - val_loss: 0.4271 - val_acc: 0.8333 - lr: 2.8147e-05
# Epoch 43/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0754 - acc: 0.9907
# Epoch 43: val_acc did not improve from 0.86667
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0754 - acc: 0.9907 - val_loss: 0.4367 - val_acc: 0.8167 - lr: 2.2518e-05
# Epoch 44/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0752 - acc: 0.9907
# Epoch 44: val_acc did not improve from 0.86667
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0752 - acc: 0.9907 - val_loss: 0.4308 - val_acc: 0.8333 - lr: 2.2518e-05
# Epoch 45/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0748 - acc: 0.9907
# Epoch 45: val_acc did not improve from 0.86667
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0748 - acc: 0.9907 - val_loss: 0.4319 - val_acc: 0.8333 - lr: 1.8014e-05
# Epoch 46/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0747 - acc: 0.9907
# Epoch 46: val_acc did not improve from 0.86667
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0747 - acc: 0.9907 - val_loss: 0.4312 - val_acc: 0.8333 - lr: 1.8014e-05
# Epoch 47/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0743 - acc: 0.9907
# Epoch 47: val_acc did not improve from 0.86667
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0743 - acc: 0.9907 - val_loss: 0.4301 - val_acc: 0.8333 - lr: 1.4412e-05
# Epoch 48/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0743 - acc: 0.9907
# Epoch 48: val_acc did not improve from 0.86667
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0743 - acc: 0.9907 - val_loss: 0.4308 - val_acc: 0.8333 - lr: 1.4412e-05
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0739 - acc: 0.9907
# Epoch 49: val_acc did not improve from 0.86667
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0739 - acc: 0.9907 - val_loss: 0.4344 - val_acc: 0.8333 - lr: 1.1529e-05
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.0737 - acc: 0.9907
# Epoch 50: val_acc did not improve from 0.86667
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0737 - acc: 0.9907 - val_loss: 0.4319 - val_acc: 0.8333 - lr: 1.1529e-05

# %%
logdir = './logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir)
# %load_ext tensorboard
# %tensorboard --logdir=./logs
# Out:
#       <iframe id="tensorboard-frame-a4a1ccb13012c711" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a4a1ccb13012c711");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# http://localhost:6006/

# %% [markdown]
# # <br><br><br><br><br>
# # 15. Conv-pooling을 활용한 CNN 구현하기

# %%
# Pooling이 없는 모델의 경우
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.summary()
# Out:
# Model: "model_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_71_input (InputLayer  [(None, 56, 56, 3)]      0
#  )
#
#  conv2d_71 (Conv2D)          (None, 56, 56, 5)         140
#
#  conv2d_72 (Conv2D)          (None, 56, 56, 5)         230
#
#  flatten_18 (Flatten)        (None, 15680)             0
#
#  dense_17 (Dense)            (None, 1)                 15681
#
# =================================================================
# Total params: 16,051
# Trainable params: 16,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Pooling이 있는 모델의 경우
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

# %%
model.summary()
# Out:
# Model: "model_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_69_input (InputLayer  [(None, 56, 56, 3)]      0
#  )
#
#  conv2d_69 (Conv2D)          (None, 56, 56, 5)         140
#
#  conv2d_70 (Conv2D)          (None, 56, 56, 5)         230
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 5)        0
#  )
#
#  flatten_17 (Flatten)        (None, 3920)              0
#
#  dense_16 (Dense)            (None, 1)                 3921
#
# =================================================================
# Total params: 4,291
# Trainable params: 4,291
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.fit(x=Train_x, y=Train_y, epochs=10, validation_data=(Test_x, Test_y), callbacks=CALLBACK)
# Out:
# Epoch 1/10
# 17/17 [==============================] - ETA: 0s - loss: 0.3986 - acc: 0.8611
# Epoch 1: val_acc did not improve from 0.88333
# 17/17 [==============================] - 1s 34ms/step - loss: 0.3986 - acc: 0.8611 - val_loss: 0.4518 - val_acc: 0.7500 - lr: 0.0010
# Epoch 2/10
# 17/17 [==============================] - ETA: 0s - loss: 0.3608 - acc: 0.8630
# Epoch 2: val_acc did not improve from 0.88333
# 17/17 [==============================] - 1s 34ms/step - loss: 0.3608 - acc: 0.8630 - val_loss: 0.4320 - val_acc: 0.7667 - lr: 0.0010
# Epoch 3/10
# 17/17 [==============================] - ETA: 0s - loss: 0.2920 - acc: 0.8833
# Epoch 3: val_acc did not improve from 0.88333
# 17/17 [==============================] - 1s 32ms/step - loss: 0.2920 - acc: 0.8833 - val_loss: 0.3452 - val_acc: 0.8667 - lr: 0.0010
# Epoch 4/10
# 16/17 [===========================>..] - ETA: 0s - loss: 0.3039 - acc: 0.8828
# Epoch 4: val_acc did not improve from 0.88333
# 17/17 [==============================] - 1s 34ms/step - loss: 0.3041 - acc: 0.8796 - val_loss: 0.3735 - val_acc: 0.8333 - lr: 0.0010
# Epoch 5/10
# 17/17 [==============================] - ETA: 0s - loss: 0.2513 - acc: 0.9000
# Epoch 5: val_acc did not improve from 0.88333
# 17/17 [==============================] - 1s 34ms/step - loss: 0.2513 - acc: 0.9000 - val_loss: 0.3203 - val_acc: 0.8833 - lr: 0.0010
# Epoch 6/10
# 17/17 [==============================] - ETA: 0s - loss: 0.2202 - acc: 0.9130
# Epoch 6: val_acc did not improve from 0.88333
# 17/17 [==============================] - 1s 34ms/step - loss: 0.2202 - acc: 0.9130 - val_loss: 0.3149 - val_acc: 0.8667 - lr: 0.0010
# Epoch 7/10
# 17/17 [==============================] - ETA: 0s - loss: 0.1886 - acc: 0.9167
# Epoch 7: val_acc did not improve from 0.88333
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1886 - acc: 0.9167 - val_loss: 0.5106 - val_acc: 0.7667 - lr: 0.0010
# Epoch 8/10
# 17/17 [==============================] - ETA: 0s - loss: 0.2398 - acc: 0.8963
# Epoch 8: val_acc did not improve from 0.88333
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 17/17 [==============================] - 1s 34ms/step - loss: 0.2398 - acc: 0.8963 - val_loss: 0.3554 - val_acc: 0.8167 - lr: 0.0010
# Epoch 9/10
# 17/17 [==============================] - ETA: 0s - loss: 0.1667 - acc: 0.9389
# Epoch 9: val_acc did not improve from 0.88333
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1667 - acc: 0.9389 - val_loss: 0.2997 - val_acc: 0.8833 - lr: 8.0000e-04
# Epoch 10/10
# 17/17 [==============================] - ETA: 0s - loss: 0.1618 - acc: 0.9389
# Epoch 10: val_acc improved from 0.88333 to 0.90000, saving model to MODEL\010-0.1618-0.9389-0.2969-0.9000.hdf5
# 17/17 [==============================] - 1s 34ms/step - loss: 0.1618 - acc: 0.9389 - val_loss: 0.2969 - val_acc: 0.9000 - lr: 8.0000e-04

# %%
Predicted = model.predict(Test_x)

CheckSame = [Pred == Label for Pred, Label in zip(Predicted>0.5, Test_y == 1)]
pd.Series(CheckSame).value_counts()

# 정확도: 54 / 60 = 90%
# Out:
# 2/2 [==============================] - 0s 29ms/step
# [True]     54
# [False]     6
# dtype: int64

# %% [markdown]
# # Stride

# %%
from IPython.display import Image
Image('stride.png')

# %%
# Pooling이 있는 모델의 경우
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(1,1) ))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

model.summary()
# Out:
# Model: "model_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_111_input (InputLaye  [(None, 56, 56, 3)]      0
#  r)
#
#  conv2d_111 (Conv2D)         (None, 56, 56, 5)         140
#
#  conv2d_112 (Conv2D)         (None, 56, 56, 5)         230
#
#  max_pooling2d_16 (MaxPoolin  (None, 55, 55, 5)        0
#  g2D)
#
#  flatten_26 (Flatten)        (None, 15125)             0
#
#  dense_26 (Dense)            (None, 1)                 15126
#
# =================================================================
# Total params: 15,496
# Trainable params: 15,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Pooling이 있는 모델의 경우
model = models.Sequential()
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.Conv2D(5, (3, 3), activation='relu', padding='same', input_shape=(56, 56, 3,)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2) ))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model = Model(inputs=model.input, outputs=model.output)

model.summary()
# Out:
# Model: "model_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_113_input (InputLaye  [(None, 56, 56, 3)]      0
#  r)
#
#  conv2d_113 (Conv2D)         (None, 56, 56, 5)         140
#
#  conv2d_114 (Conv2D)         (None, 56, 56, 5)         230
#
#  max_pooling2d_17 (MaxPoolin  (None, 28, 28, 5)        0
#  g2D)
#
#  flatten_27 (Flatten)        (None, 3920)              0
#
#  dense_27 (Dense)            (None, 1)                 3921
#
# =================================================================
# Total params: 4,291
# Trainable params: 4,291
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br><br><br><br><br>
# # 16. VGG 논문 구현하기

# %% [markdown]
# Title: Very Deep Convolutional Networks for Large-Scale Image Recognition<br>
# Search: scholar.google.com

# %% [markdown]
# https://arxiv.org/pdf/1409.1556.pdf

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(224,224,3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

################# 여기까지가 CNN, 아래부터는 Fully connected layers

model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=1000, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d_13 (ZeroPadd  (None, 226, 226, 3)      0
#  ing2D)
#
#  conv2d_92 (Conv2D)          (None, 224, 224, 64)      1792
#
#  zero_padding2d_14 (ZeroPadd  (None, 226, 226, 64)     0
#  ing2D)
#
#  conv2d_93 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_9 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  zero_padding2d_15 (ZeroPadd  (None, 114, 114, 64)     0
#  ing2D)
#
#  conv2d_94 (Conv2D)          (None, 112, 112, 128)     73856
#
#  zero_padding2d_16 (ZeroPadd  (None, 114, 114, 128)    0
#  ing2D)
#
#  conv2d_95 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_10 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  zero_padding2d_17 (ZeroPadd  (None, 58, 58, 128)      0
#  ing2D)
#
#  conv2d_96 (Conv2D)          (None, 56, 56, 256)       295168
#
#  zero_padding2d_18 (ZeroPadd  (None, 58, 58, 256)      0
#  ing2D)
#
#  conv2d_97 (Conv2D)          (None, 56, 56, 256)       590080
#
#  zero_padding2d_19 (ZeroPadd  (None, 58, 58, 256)      0
#  ing2D)
#
#  conv2d_98 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_11 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  zero_padding2d_20 (ZeroPadd  (None, 30, 30, 256)      0
#  ing2D)
#
#  conv2d_99 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  zero_padding2d_21 (ZeroPadd  (None, 30, 30, 512)      0
#  ing2D)
#
#  conv2d_100 (Conv2D)         (None, 28, 28, 512)       2359808
#
#  zero_padding2d_22 (ZeroPadd  (None, 30, 30, 512)      0
#  ing2D)
#
#  conv2d_101 (Conv2D)         (None, 28, 28, 512)       2359808
#
#  max_pooling2d_12 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  zero_padding2d_23 (ZeroPadd  (None, 16, 16, 512)      0
#  ing2D)
#
#  conv2d_102 (Conv2D)         (None, 14, 14, 512)       2359808
#
#  zero_padding2d_24 (ZeroPadd  (None, 16, 16, 512)      0
#  ing2D)
#
#  conv2d_103 (Conv2D)         (None, 14, 14, 512)       2359808
#
#  zero_padding2d_25 (ZeroPadd  (None, 16, 16, 512)      0
#  ing2D)
#
#  conv2d_104 (Conv2D)         (None, 14, 14, 512)       2359808
#
#  max_pooling2d_13 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  flatten_23 (Flatten)        (None, 25088)             0
#
#  dense_21 (Dense)            (None, 4096)              102764544
#
#  dense_22 (Dense)            (None, 4096)              16781312
#
#  dense_23 (Dense)            (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
VGGModel = tf.keras.applications.VGG16(include_top=True,
    weights='imagenet', input_shape=(224,224,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 55s 0us/step

# %%
VGGModel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Final layer 없이 VGG16 불러오기

# %%
VGGModel = tf.keras.applications.VGG16(include_top=False,
    weights='imagenet', input_tensor=None,
    input_shape=(224,224,3), pooling=None)

# %%
VGGModel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 17. 일반 이미지 Pretrained model에 넣어보기

# %% [markdown]
# https://image.dongascience.com/Photo/2020/03/15856430426741.jpg

# %%
VGGModel = tf.keras.applications.VGG16(include_top=True,
    weights='imagenet', input_shape=(224,224,3))

# %%
VGGModel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
from PIL import Image
import requests

url = 'https://image.dongascience.com/Photo/2020/03/15856430426741.jpg'
image = Image.open(requests.get(url, stream=True).raw)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=308x400>

# %%
image = tf.keras.preprocessing.image.img_to_array(image)
image.shape
# Out:
# (400, 308, 3)

# %%
image = cv2.resize(image, (224, 224) )
image.shape
# Out:
# (224, 224, 3)

# %%
image = np.expand_dims(image, axis=0)
image.shape
# Out:
# (1, 224, 224, 3)

# %%
plt.imshow(image[0]/255, interpolation='nearest')
plt.show()

# %%
image = tf.keras.applications.vgg16.preprocess_input(image)
image.shape
# Out:
# (1, 224, 224, 3)

# %%
Predicted = VGGModel.predict(image)
# Out:
# 1/1 [==============================] - 0s 311ms/step

# %%
tf.keras.applications.vgg16.decode_predictions(Predicted)
# Out:
# [[('n02112018', 'Pomeranian', 0.99051064),
#   ('n02086079', 'Pekinese', 0.0019064707),
#   ('n02112350', 'keeshond', 0.0007786995),
#   ('n04399382', 'teddy', 0.0007474987),
#   ('n02112137', 'chow', 0.0007094604)]]

# %%
from tensorflow.keras.applications.vgg16 import decode_predictions

url = 'https://ichef.bbci.co.uk/news/640/cpsprodpb/0C17/production/_110059030_j8aged72breaches_copyright_kennethbalcombcenterforwhaleresearch_20051011kcb_dg1-116.jpg'
image = Image.open(requests.get(url, stream=True).raw)
image = tf.keras.preprocessing.image.img_to_array(image)
image = cv2.resize(image, (224, 224) )
image = np.expand_dims(image, axis=0)
plt.imshow(image[0]/255, interpolation='nearest')
plt.show()
image = tf.keras.applications.vgg16.preprocess_input(image)

# %%
print(decode_predictions(VGGModel.predict(image)))
# Out:
# 1/1 [==============================] - 0s 266ms/step
# [[('n02071294', 'killer_whale', 0.9999181), ('n02066245', 'grey_whale', 8.1057115e-05), ('n02056570', 'king_penguin', 3.8157214e-07), ('n02077923', 'sea_lion', 2.2249586e-07), ('n01484850', 'great_white_shark', 4.7191016e-08)]]

# %% [markdown]
# <br><br><br><br>
# # 18. Global Average Pooling

# %% [markdown]
# 모델 구현

# %%
VGGModel = tf.keras.applications.VGG16(include_top=False,
    weights='imagenet', input_tensor=None,
    input_shape=(224,224,3), pooling=None)

x = GlobalAveragePooling2D()(VGGModel.output)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=VGGModel.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_29 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 14,715,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# learning parameter를 더하여 최종 model compile
model.compile(optimizer='adam',
         loss='binary_crossentropy',
         metrics=['acc']
)

# %% [markdown]
# 데이터 준비

# %%
ImageSize = (224, 224)

Train_x = []
Train_y = []
for FileName in os.listdir('TRAIN/akiec/'):
    Train_x.append(PIL.Image.open('TRAIN/akiec/' + FileName).resize(ImageSize))
    Train_y.append(0)
    
for FileName in os.listdir('TRAIN/melanoma/'):
    Train_x.append(PIL.Image.open('TRAIN/melanoma/' + FileName).resize(ImageSize))
    Train_y.append(1)

# List로 모든 이미지 읽은 후, numpy array로 수정
Test_x = []
Test_y = []
for FileName in os.listdir('Test/akiec/'):
    Test_x.append(PIL.Image.open('Test/akiec/' + FileName).resize(ImageSize))
    Test_y.append(0)
    
for FileName in os.listdir('Test/melanoma/'):
    Test_x.append(PIL.Image.open('Test/melanoma/' + FileName).resize(ImageSize))
    Test_y.append(1)

# %%
Train_x = np.stack(Train_x, axis=0 )
Train_y = np.array(Train_y)

Test_x = np.stack(Test_x, axis=0 )
Test_y = np.array(Test_y)

# %% [markdown]
# # Fine tunning

# %%
# CheckPoint: Epoch 마다 validation 성능을 검증하여, best performance 일 경우 저장
CP = ModelCheckpoint(filepath='MODEL/{epoch:03d}-{loss:.4f}-{acc:.4f}-{val_loss:.4f}-{val_acc:.4f}.hdf5',
            monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# Learning Rate 줄여나가기
LR = ReduceLROnPlateau(monitor='val_loss',factor=0.8,patience=2, verbose=1, min_lr=1e-8)

CALLBACK = [CP, LR]

# %%
model.predict(Train_x[:5])
# Out:
# 1/1 [==============================] - 1s 971ms/step
# array([[0.991412  ],
#        [0.98547554],
#        [0.7172076 ],
#        [0.97629786],
#        [0.9965001 ]], dtype=float32)

# %%
Train_x[:10].shape
# Out:
# (10, 224, 224, 3)

# %%
model.fit(x=Train_x[:10], y=Train_y[:10])
# Out:
# 1/1 [==============================] - 7s 7s/step - loss: 4.0169 - acc: 0.0000e+00

# %%
model.fit(x=Train_x, y=Train_y)
# Out:
#  2/17 [==>...........................] - ETA: 4:58 - loss: 557.1771 - acc: 0.4531
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [587], in <module>
# ----> 1 model.fit(x=Train_x, y=Train_y)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 너무 느리고, 모든 데이터를 한번에 넣는 것은 성능 저하를 초래

# %% [markdown]
# <br><br><br><br><br>
# # 19. Generator with VGG16

# %%
import tensorflow as tf
import numpy as np

import pandas as pd
import cv2
import os
import math
import scipy as sp
import PIL

# Tensorflow
from tensorflow.keras import models, layers, Model
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout, ZeroPadding2D

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import EfficientNetB4, EfficientNetB6, ResNet50V2
#from keras_tuner.tuners import RandomSearch

import scikitplot as skplt
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
# batch_size: 한번에 forward & Backword 하는 샘플의 수
batch_size = 32

# Training 수
epochs = 50

# Weight 조절 parameter
LearningRate = 1e-3 # 0.001
Decay = 1e-6

img_width = 224
img_height = 224

# %%
# 디렉토리 경로 설정 필요
CurrentDirectory = "./"

train_directory = CurrentDirectory + 'TRAIN/'
test_directory  = CurrentDirectory + 'TEST/'
model_directory = CurrentDirectory + 'MODEL/'
tensorboard_directory = CurrentDirectory + 'Tensorboard'

# %% [markdown]
# <모델 정의하기>

# %%
VGGModel = tf.keras.applications.VGG16(include_top=False,
    weights='imagenet', input_tensor=None,
    input_shape=(224,224,3), pooling=None)

x = GlobalAveragePooling2D()(VGGModel.output)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=VGGModel.input, outputs=predictions)

# %%
model.compile(optimizer='adam',
         loss='binary_crossentropy',
         metrics=['acc']
) # 나이를, MSE

# %% [markdown]
# <Training / Validation data with generator>

# %%
# Online-augmentation 적용 Generator
# 1. 이미지를 전부다 불러서 램 (메모리)에 올릴 수 없기 때문
# 2. 이미지는 Augmentation을 해주는게 좋아서

DATAGEN_TRAIN = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=True,
    data_format="channels_last",
    validation_split=0.10) # Train / Validation

# %%
TRAIN_GENERATOR = DATAGEN_TRAIN.flow_from_directory(
    train_directory,
    classes=["akiec", "melanoma"],
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode= "binary", # category 일 경우 -> Final layer: unit2 softmax
    subset = "training")

VALID_GENERATOR = DATAGEN_TRAIN.flow_from_directory(
    train_directory,
    classes=["akiec", "melanoma"],
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode= "categorical",
    subset = "validation")
# Out:
# Found 486 images belonging to 2 classes.
# Found 54 images belonging to 2 classes.

# %% [markdown]
# < Test data with generator >

# %%
DATAGEN_TEST = ImageDataGenerator(
    rescale=1./255,
    featurewise_center=True,
    featurewise_std_normalization=True,
    data_format="channels_last")

# %%
# 중요한 argument: shuffle
# 중요한 argument: class_mode

TEST_GENERATOR = DATAGEN_TEST.flow_from_directory(
    test_directory,
    classes=["akiec", "melanoma"],
    target_size = (img_height, img_width),
    batch_size = batch_size,
    shuffle = False,
    class_mode='binary')
# Out:
# Found 60 images belonging to 2 classes.

# %% [markdown]
# ## Fine tunning

# %%
# CheckPoint: Epoch 마다 validation 성능을 검증하여, best performance 일 경우 저장
CP = ModelCheckpoint(filepath='MODEL/{epoch:03d}-{loss:.4f}-{acc:.4f}-{val_loss:.4f}-{val_acc:.4f}.hdf5',
            monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# Learning Rate 줄여나가기
LR = ReduceLROnPlateau(monitor='val_loss',factor=0.8,patience=2, verbose=1, min_lr=1e-8)

CALLBACK = [CP, LR]

# %%
model.fit_generator(
    TRAIN_GENERATOR,
    epochs=20,
    callbacks=CALLBACK,
    shuffle=True,
    validation_data=TEST_GENERATOR)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6240\4032691314.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py:1663: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py:1671: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/20
#  2/16 [==>...........................] - ETA: 34s - loss: 3.1686 - acc: 0.5263
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [614], in <module>
# ----> 1 model.fit_generator(
#       2     TRAIN_GENERATOR,
#       3     epochs=20,
#       4     callbacks=CALLBACK,
#       5     shuffle=True,
#       6     validation_data=TEST_GENERATOR)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:2260, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2249 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2250
#    2251 DEPRECATED:
#    2252   `Model.fit` now supports generators, so there is no longer any need to use
#    2253   this endpoint.
#    2254 """
#    2255 warnings.warn(
#    2256     '`Model.fit_generator` is deprecated and '
#    2257     'will be removed in a future version. '
#    2258     'Please use `Model.fit`, which supports generators.',
#    2259     stacklevel=2)
# -> 2260 return self.fit(
#    2261     generator,
#    2262     steps_per_epoch=steps_per_epoch,
#    2263     epochs=epochs,
#    2264     verbose=verbose,
#    2265     callbacks=callbacks,
#    2266     validation_data=validation_data,
#    2267     validation_steps=validation_steps,
#    2268     validation_freq=validation_freq,
#    2269     class_weight=class_weight,
#    2270     max_queue_size=max_queue_size,
#    2271     workers=workers,
#    2272     use_multiprocessing=use_multiprocessing,
#    2273     shuffle=shuffle,
#    2274     initial_epoch=initial_epoch)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
