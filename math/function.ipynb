# %% [markdown]
# <a href="https://colab.research.google.com/github/y001003/yeardream/blob/main/math/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 알바생 A or B

# %%
days = 31

A = np.array([1000000 for i in range(days)])
print(f"{np.sum(A):,d}")
# Out:
# 31,000,000

# %%
B = np.array([2**i for i in range(days)])
print(f"{np.sum(B):,d}")
# Out:
# 2,147,483,647

# %%
fig = plt.figure(figsize=(5,10))
ax = plt.axes()

ax.plot(range(days), np.cumsum(A), label='A')
ax.plot(range(days), np.cumsum(B), label='B')
ax.legend()

plt.show()

# %% [markdown]
# ## MSE vs MSLE

# %%
gt_1 = 10
pred_1 = 15

gt_2 = 1000
pred_2 = 1005

def mse(pred, gt):
    return (pred - gt)**2

def msle(pred, gt):
    return (np.log(pred+1) - np.log(gt+1))**2

print(f"mse 1:{mse(pred_1, gt_1):.6f}")
print(f"mse 2:{mse(pred_2, gt_2):.6f}")

print(f"msle 1:{msle(pred_1, gt_1):.6f}")
print(f"msle 2:{msle(pred_2, gt_2):.6f}")
# Out:
# mse 1:25.000000
# mse 2:25.000000
# msle 1:0.140395
# msle 2:0.000025

# %% [markdown]
# ## 2 변수 스칼라 함수 시각화

# %%
from ipywidgets import interact
import ipywidgets as widgets

# %%
@interact( x=widgets.IntSlider(min=2, max=20, step=1, value=2) )
def draw_func(x):
    fig = plt.figure(figsize=(7,7))
    ax = plt.axes(projection='3d')

    ax.xaxis.set_tick_params(labelsize=15)
    ax.yaxis.set_tick_params(labelsize=15)
    ax.zaxis.set_tick_params(labelsize=15)
    ax.set_xlabel(r'$x_1$', fontsize=20)
    ax.set_ylabel(r'$x_2$', fontsize=20)
    ax.set_zlabel(r'$z$', fontsize=20)

    x1 = np.linspace(-2, 2, x)
    x2 = np.linspace(-1, 3, x)
    X1, X2 = np.meshgrid(x1, x2)
    Z = 50*(X2 - X1**2)**2 + (2-X1)**2

    # ax.scatter3D(X1, X2, Z, marker='.', color='C1')
    ax.plot_surface(X1, X2, Z, cmap=plt.cm.binary, edgecolor="k")

    plt.show()
# Out:
# interactive(children=(IntSlider(value=2, description='x', max=20, min=2), Output()), _dom_classes=('widget-int…
