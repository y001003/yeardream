# %% [markdown]
# <a href="https://colab.research.google.com/github/y001003/yeardream/blob/main/sql/SQL_%E1%84%8B%E1%85%B5%E1%86%B8%E1%84%86%E1%85%AE%E1%86%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CS필수과목 : 자료구조, 알고리즘, 데이터베이스, 운영체제, 네트워크, 컴퓨터구조, 프로그래밍언어론(또는 오토마타)
#
# 한 권으로 읽는 컴퓨터 구조와 프로그래밍:더 나은 소프트웨어 개발을 위한 하드웨어
# http://www.yes24.com/Product/Goods/98997716

# %% [markdown]
# AI논문을 읽고 reproduce를 할 수 있는 능력을 갖출 수 있어야 한다...
# 논문을 읽고 코드로 구현한다?

# %% [markdown]
# 데이터 엔지니어
# 분산처리시스템 : 하둡 에코시스템 카프카  등
# 데이터베이스 RDB ERD

# %% [markdown]
# 엔지니어라면 어떤 개발환경 혹은 기술을 사용하는 이유 및 장단점을 명확하게 알고 있어야 한다.
# ex)DB Mysql을 쓰는 이유

# %% [markdown]
# # 데이터 베이스 1일차

# %% [markdown]
# ## 1. 데이터 베이스란?

# %% [markdown]
# 데이터를 체계적으로 관리할 수 있는 공간을 Database로 정의한다.
# 그 데이터를 관리하는 시스템을 DBMS라고 한다. ex) oracle, mariaDB, mySQL 등

# %% [markdown]
# ## 2. 데이터베이스를 사용하는 이유

# %% [markdown]
# 데이터베이스 개념 이전에는 File 단위로 데이터를 관리, ex) 윈도우 탐색기, macOS Finder 등

# %% [markdown]
# - 문제점
#  - Redundancy, Inconsistency
#  - Isolation, Integrity
#  - Atomicity, Concurrency
#
# 데이터가 여러 형태로 여기저기 저장되면서 통일성을 잃고
# 데이터를 처리하기 위해 매번 특정 application이 필요할수 있음
# 데이터에 즉각적으로 접근하기 힘들다.
# 파일의 일부가 수정되었을때, 전체적인 데이터가 통일성을 유지하기가 힘들다..
#
# --> 관리가 불편하다.
#
# 데이터베이스 정리를 하면 --> 원하는 것을 빠르게 찾을 수 있다. 즉 관리가 잘된다.
#
# 규격화된 시스템안에 데이터를 체계적으로 정리를 하는 것
# <code> 정형 데이터 (Structural data = panel data = tabular data) </code>
#
# DB 엔지니어라면 어떤 DB를 사용해야 데이터베이스를 잘 관리할 수 있을지 고민해 봐야 한다!!

# %% [markdown]
# ## 3. RDBMS : Relational Database Management System

# %% [markdown]
# ![스크린샷 2022-04-28 오전 9.05.43.png](data:image/png;base64,...)

# %% [markdown]
# > PK로 숫자를 쓰는 이유 : Binary Search 알고리즘을 이용해 검색을 하기 위해서 --> Binary Search 알고리즘이 가장 빠르다. Binary Search 조건: 크기 비교가 가능해야한다. well-ordering 가능해야한다.
# >> 사실 B+ 트리를 이용하면 더 빠르다. - 데이터를 딥하게 파고싶으면!( 데이터 엔지니어 ? )

# %% [markdown]
# ### Binary Search Tree

# %% [markdown]
# [1,2,3,5,7,9,11].
# O(log2N) 속도
#
# log 타임이면 엄청 빠르다.

# %% [markdown]
# ### SQL : Structured Query Language(SQL)

# %% [markdown]
# DBMS와 사용자가 소통하기 위해 정의된 언어
#
# - DDL(Data Definition Language):
#     - CREATE, DROP, ALTER, TRUNCATE
#     - 테이블을 다룰때 사용, table_level에서 사용
# - DML(Data Manipulation Languege) :
#     - INSERT, UPDATE, DELETE, SELECT
#     - 데이터를 처리할 때 사용, row_level에서 사용
# - DCL(Data Control Language) :
#     - GRANT, REVOKE, COMMIT, ROLLBACK, LOCK
#     - 데이터베이스에 필요한 여러가지 부가기능
#     - 관리권한, 데이터베이스 저장 확인, 데이터베이스 회귀 등

# %% [markdown]
# ### Cursor(커서)

# %% [markdown]
# Python, Java, C++ 등의 언어를 이용해서, 절차적으로 명령을 수행하고 싶을 때 사용하는 개념
#
# DBMS에 접근해서 DBMS를 조작하는 개념

# %% [markdown]
# 맥북을 많이 쓰는 이유 : 리눅스 구조와 매우 닮았기 때문에 : 리눅스 가볍고 빠른 기본적인 기능만 있는 운영체제 -> 개발하기 편하다

# %% [markdown]
# ### DB 설계 Logical Schema

# %% [markdown]
# - DB의 설계도
# - 기능명세 : 개발할 어플리케이션에 어떤 기능이 있고 그에 따른 DB Table은 뭐가 필요할지 설계해본다
# - DB를 구성하고 있는 테이블과 테이블 사이의 관계를 정의
# - ERD(Entitiy-RelatioinShip Diagram)을 이용해서 정의한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
